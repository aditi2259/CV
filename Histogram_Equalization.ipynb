# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi2259/CV/blob/main/Histogram_Equalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"/content/download.jpeg", cv2.IMREAD_GRAYSCALE)
final_image = cv2.equalizeHist(img)

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=L size=417x266>
# <PIL.Image.Image image mode=L size=417x266>

# %%
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Original Image Histogram')
plt.show()

plt.hist(final_image.ravel(), 256, [0, 256])
plt.title('Equalized Image Histogram')
plt.show()
# Out:
# <ipython-input-11-8bbb396d8bc0>:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])
# <ipython-input-11-8bbb396d8bc0>:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(final_image.ravel(), 256, [0, 256])
